# %% [markdown]
# from gensim.models import Word2Vec
# model = Word2Vec.load_word2vec_format('word2vec.bin')

# %%
from gensim.models import Word2Vec 
model = Word2Vec.load_word2vec_format('word2vec.bin', binary=True)

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib
import matplotlib.pyplot as plt
import re
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import pairwise_distances
from nltk.util import ngrams as nltk_ngrams
from collections import Counter
import networkx as nx

custom_stopwords = ['rt', '&amp', '#', '', '&amp;', '-', 'amp', '.', 'QQQQQQQQQ', 'll','re','ve']
stopwords_english = stopwords.words('english')
stopwords_spanish = stopwords.words('spanish')
tknzr = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

# %%
data = pd.read_csv('/home/dima/Downloads/jan.csv')

# %%
def is_word_blacklisted(word):
    return word.startswith('http') or \
           word.startswith('//') or \
           word.startswith('@') or \
           word.startswith('#') or \
           word in custom_stopwords or \
           word in stopwords_english or \
           word in stopwords_spanish

def clean_text(text, remove_non_chars=True):
    new_text = re.sub(r'@\S+', '', text)
    new_text = re.sub(r'#\S+', '', new_text)
    new_text = re.sub(r',', '.', new_text)
    new_text = re.sub(r"'", ' ', new_text)
    new_text = re.sub(r'https://\S+', '', new_text)
    new_text = re.sub(r'http://\S+', '', new_text)
    words = tknzr.tokenize(new_text)

    if remove_non_chars:
        words = [re.sub(r'\W+', ' ', w) for w in words]

    return ' '.join([w for w in words if not is_word_blacklisted(w)])

def get_tweet_vector(text):
    words = text.split()
    N = len(words)
    vector = np.zeros(300)
    
    if N > 0:
        for word in words:
            if word in model:
                vector += model[word]
        vector /= N
    return vector

def find_all_paths(G):
    result = []
    try:
        result = []
        start_nodes = [k for k,v in G.in_degree().iteritems() if v == 0]

        for start in start_nodes:
            paths = nx.shortest_path(G, start)
            longest = max(paths, key= lambda x: len(set(paths[x])))
            result.append(paths[longest])
    except Exception as e:
        logging.info("Error, " + e.message)

    return result

def get_path_tuple(p, l):
    d= dict(l)
    prev = p[0]
    sum = 0
    count = 0
    min_cnt = 9999999
    min_term = ''
    phrase = p[0].split()[0]
    for i in range(1, len(p)):
        terms  = (prev + ' ' + p[i]).split()
        term = terms[0] + ' ' + terms[1] + ' ' + terms[3]

        if term in d:
            cnt = d[term]

            if cnt < min_cnt:
                min_cnt = cnt
                min_term = term

            count+=1
            sum += cnt

        prev = p[i]
        phrase += ' ' + p[i].split()[0]

    phrase += ' ' +  p[-1].split()[1]
    return phrase, min_cnt, min_term

def build_phrases_from_aggs(aggs):
    l = sorted(aggs, key=lambda x: x[1], reverse=True)

    G = nx.DiGraph()
    for i in range(len(l)):

        bgram = l[i][0]
        count = l[i][1]
        terms = bgram.split()

        term1 = terms[0] + ' ' + terms[1]
        term2 = terms[1] + ' ' + terms[2]

        G.add_edge(term1, term2, weight=count)

    paths = find_all_paths(G)
    phrases = [get_path_tuple(p,l) for p in paths]

    keys = list(set([x[2] for x in phrases]))
    d = [( k , [(x[0],x[1]) for x in phrases if x[2] == k]) for k in keys]

    result = [{'phrase' : v[0][0], 'count' : v[0][1], 'alias' : k} for k,v in dict(d).iteritems()]


    return sorted(result, key=lambda x : x['count'], reverse=True)


def get_grams(text):
    return [ ' '.join(g) for g in nltk_ngrams(text.split(),3)]

def get_cluster_phrases(cluster_tweets):
    cnt = Counter()
    for t in cluster_tweets:
        cnt.update(get_grams(t))
    return build_phrases_from_aggs(cnt.most_common(10))[:2]


def get_cluster_top_words(cluster_tweets):
    big_text = ' '.join(cluster_tweets)
    cnt = Counter(big_text.split())
    return cnt.most_common(10)

# %%
data = data[~data['Body'].str.contains('@OfficialJimRohn')]
data = data[~data['Body'].str.startswith('RT @')]
data['Body_clean'] = data['Body']
data['Body_clean'] = data['Body_clean'].apply(clean_text)
data = data.reset_index()
len(data)
# Out:
# 7119

# %%
vectors = []
for i in range(len(data)):
    tweet_vector = get_tweet_vector(data['Body_clean'][i])
    vectors.append(tweet_vector)
len(vectors)
# Out:
# 7119

# %%
num_of_clusters = 100
y = KMeans(n_clusters=num_of_clusters,n_jobs=3).fit_predict(vectors)
clusters = {}
for i in range(len(y)):
    if y[i] not in clusters:
        clusters[y[i]] = {'tweets' : [], 'vectors' : [], 'tweets_clean' : []}
    clusters[y[i]]['tweets'].append(data['Body'][i])
    clusters[y[i]]['tweets_clean'].append(data['Body_clean'][i])
    clusters[y[i]]['vectors'].append(vectors[i])
    
distance_sum = 0
distance_count = 0
for cluster_index, cluster in clusters.iteritems():
    clusters[cluster_index]['distance'] = np.sum(pairwise_distances(cluster['vectors'])) / (2 * len(cluster['vectors']))
    
    if clusters[cluster_index]['distance'] > 0:
        distance_count += 1
        distance_sum += clusters[cluster_index]['distance']
        
avg_distance = distance_sum / distance_count
print 'avg distance: ' + str(avg_distance)
# Out:
# avg distance: 52.4542159983

# %%
clusters_array = [clusters[k] for k,v in clusters.iteritems() if len(clusters[k]['tweets']) > 10]

# %%
C = sorted(clusters_array, key=lambda x: x['distance'])

# %%
print ''
for i in range(len(C)):
    print 'Topic (' + str(i) + ') Number of Tweets: ' + str(len(C[i]['tweets'])) + ', D: ' + str(C[i]['distance'])
    print '-------------------------------------------------------------------------------------------'
    words = get_cluster_top_words(C[i]['tweets_clean'])
    print 'Top Words:'
    print words
    phrases = get_cluster_phrases(C[i]['tweets_clean'])
    print '\nPhrases:'
    for phrase in phrases:
        print phrase['phrase'] + ' (' + str(phrase['count']) + ')'
    print '\nExamples:'
    for t in C[i]['tweets'][:10]:
        print t 
    print ''
# Out:
# Topic (0) Number of Tweets: 12, D: 0.0
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'thank', 12)]
#
# Phrases:
#
# Examples:
# Thank you @CarolSankar 😘 https://t.co/Amf1rFhno6
# @mcannon79 @JoC_AWC Thank you...😊
# Thank you @iamthatgirl ♥ http://twitter.com/DolansBrasil/status/744293648246935552/photo/1
# @Ravager619 @TheMarySue thank you
# @AAUWPolicy @AAUW Thank you!
# .@GCGodfrey @MickTKipper @USabadini @BlueShareForum @smarkus @GeorgeO @AbdelQaader @Sentifi_UK @GlobalFXTrader1 Thank you for ❤/RT🙏😃#TRADING
# @iamthatgirl Thank YOU! 🙈💖
# Thank you for this. https://t.co/SOi4EQVQF2
# @Pennwomen thank you!
# @SalesforceAmy @Applango @GirlsWhoCode @BlackGirlsCode thank you!! 👍🏻🙋🏻
#
# Topic (1) Number of Tweets: 11, D: 0.0
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'staggering', 11), (u'keynote', 11), (u'stats', 11), (u'founder', 11)]
#
# Phrases:
# staggering stats keynote founder (11)
#
# Examples:
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/SGh29pE130 http://twitter.com/RondaOnSecurity/status/742511611655553024/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/uFz7Mhm7Bh http://twitter.com/oicuon/status/742511612305674244/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/BwB3bHyFe6 http://twitter.com/0_1_0_0_1_0_1_0/status/742511612305637376/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/MXWjqvIVu4 http://twitter.com/thought1337er/status/742511611676524544/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/fpwFg7yYoT http://twitter.com/NX_AS10K/status/741240420496080900/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/Kr8dRxJgQx http://twitter.com/josue_fig/status/741240417694273536/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/a9IRK9kXLW http://twitter.com/jmmj_cork/status/741240417002217472/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/7WbNa5PKvk http://twitter.com/FE_AXas/status/741240416998039552/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/6adW7pqtO8 http://twitter.com/Dada73731/status/741152711157125121/photo/1
# Staggering stats #NACE16 keynote @GirlsWhoCode founder @reshmasaujani #womenintech... https://t.co/9KHrKz6NCO http://twitter.com/lafollyfamily/status/741152710632837120/photo/1
#
# Topic (2) Number of Tweets: 11, D: 4.01502656499e-07
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'array', 11), (u'awc', 11), (u'invite', 11)]
#
# Phrases:
# awc array invite (11)
#
# Examples:
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihuNfL
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
# AWC #Solar Array #Presidential Invite https://t.co/0oMPihdcod
#
# Topic (3) Number of Tweets: 100, D: 1.49011611938e-06
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'scupper', 100), (u'goodies', 100), (u'chances', 100), (u'competition', 100), (u'want', 100), (u'entered', 100), (u'bunch', 100)]
#
# Phrases:
# entered competition bunch goodies want scupper chances (100)
#
# Examples:
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/eAVdpZTQex
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/itnUDFwOgm
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/Iz34oNDHJt
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/4flJXjd2li
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/ylXFqs2vIY
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/RPp0cMhDIF
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/dOhvEMyRD8
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/gRMd7QNWUR
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/CMaWHJ0dUk
# I just entered the @virginexp @FitbitUK competition to #win a bunch of goodies. Want to scupper my chances? https://t.co/tauxolaAdl
#
# Topic (4) Number of Tweets: 37, D: 1.08264477907
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'like', 37), (u'girls', 37), (u'boss', 37), (u'added', 36), (u'photo', 36), (u'new', 36), (u'updated', 1), (u'cover', 1), (u'photos', 1), (u'5', 1)]
#
# Phrases:
# like boss girls added 5 new photos (1)
#
# Examples:
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105699806168600/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105699672835280/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105670799504834/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105391529532761/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105673826171198/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105686826169898/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105686589503255/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105674239504490/?type=3
# Like A Boss Girls added a new photo.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105656756172905/?type=3
# Like A Boss Girls added 5 new photos.  https://www.facebook.com/LikeaBossGirls/photos/a.220273281377928.55677.146706028734654/1105654296173151/?type=3
#
# Topic (5) Number of Tweets: 11, D: 1.46261964922
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'truth', 11), (u'simple', 1)]
#
# Phrases:
#
# Examples:
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1169587666447431/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1169213923151472/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1166944733378391/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1166937633379101/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1166840663388798/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1166210003451864/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1164491923623672/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1164491446957053/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1164249433647921/?type=3
# Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1164232850316246/?type=3
#
# Topic (6) Number of Tweets: 20, D: 2.86265532463
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'3', 20), (u'care', 1), (u'pass', 1)]
#
# Phrases:
#
# Examples:
# Pass it on <3  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1169885876417610/?type=3
# <3  https://www.facebook.com/YourPositiveOasis/photos/a.1551527028463666.1073741829.1531105223839180/1720770701539297/?type=3
# <3  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1169823776423820/?type=3
# &lt;3 https://t.co/y3LoQfmS7U
# <3  https://www.facebook.com/ChangeYourThoughtsToday/photos/a.10150576500961439.375979.286849021438/10153640997921439/?type=3
# <3  https://www.facebook.com/AnikSingalcom/photos/a.201462843247984.49051.106673549393581/1095433930517533/?type=3
# <3  https://www.facebook.com/TerriColeLCSW/photos/a.188779841142100.40016.187679857918765/1206027336084007/?type=3
# <3  https://www.facebook.com/TerriColeLCSW/photos/a.188779841142100.40016.187679857918765/1205338012819606/?type=3
# <3  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1167421266664071/?type=3
# <3  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1166945273378337/?type=3
#
# Topic (7) Number of Tweets: 13, D: 5.23309289243
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'yes', 15), (u'please', 2), (u'thx', 1), (u'hex', 1), (u'table', 1), (u'must', 1)]
#
# Phrases:
#
# Examples:
# YES.  http://trib.al/ajlgmdg
# YES  http://www.purewow.com/food/champagne-ice-cube-recipe?utm_medium=social&utm_source=facebook
# @my2k @TheMarySue yes please
# YES 💕 #yogaforkids https://t.co/fYYNFc7qQt
# Yes!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1167716976634500/?type=3
# @TheMarySue @NPRCodeSwitch @katchow @RadioMirage yes
# Yes, yes, and yes! #women must be at the table! Thx @AAUW @USWomen2016 #womenonboards  https://t.co/gBNbp9ZPXT
# Yes. They do. @TheMarySue https://t.co/vZeGtluB7g
# YES!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1164240863648778/?type=3
# @luna_leigh93 @MissAlexisJones @thatgirlgreener yes please !
#
# Topic (8) Number of Tweets: 21, D: 5.42384793216
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'ceo', 21), (u'coming', 19), (u'vegas', 18), (u'join', 17), (u'founder', 3), (u'author', 2), (u'radio', 2)]
#
# Phrases:
# ceo coming vegas join (17)
# radio founder ceo author coming vegas join (1)
#
# Examples:
# #Girlboss Radio: @EllevateNtwk's @kmin, Founder and CEO of @dailymuse https://t.co/XfwU8mkB49 http://twitter.com/EllevateNtwk/status/744520125999648769/photo/1
# #Girlboss Radio: @EllevateNtwk's @kmin, Founder and CEO of @dailymuse https://t.co/XfwU8mkB49 http://twitter.com/EllevateNtwk/status/743888564837036032/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/Hs49LRnSWc http://twitter.com/PaolaLastick/status/743838159201525760/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/2422NfrMQQ http://twitter.com/JonOConnell86/status/743474156897964032/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/6JHbAxl4XT http://twitter.com/kallder04/status/743413690758758400/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/UIPhtNDUmI http://twitter.com/CathyGoodrich1/status/743217092237885440/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/qnocLO52Vt http://twitter.com/karenhuss/status/743201976029184000/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/1q6uH9LhVw http://twitter.com/larrydunivan/status/743187449636061184/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/0yckRAMAch http://twitter.com/Amostiguy/status/743187017022980096/photo/1
# CEO of @GirlsWhoCode, @reshmasaujani is coming to #CeridianINSIGHTS in Las Vegas! Join:  https://t.co/NiPenCTH1I http://twitter.com/jaysonsaba/status/743107115590504448/photo/1
#
# Topic (9) Number of Tweets: 25, D: 6.10425162751
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'perspective', 25), (u'higher', 25), (u'3', 3), (u'coachkimi', 1), (u'incredible', 1), (u'brilliant', 1), (u'thanks', 1), (u'gazing', 1)]
#
# Phrases:
# brilliant higher perspective 3 (1)
# gazing higher perspective 3 (1)
#
# Examples:
# Higher Perspective  https://www.facebook.com/simpleorganiclife/photos/a.1622840937935666.1073741828.1611648809054879/1792628914290200/?type=3
# Incredible! Higher Perspective  https://www.facebook.com/exploristscience/videos/947546145343582/
# Higher Perspective https://t.co/4FNHRmzmvC
# 󾬓󾬓 *Higher Perspective* https://t.co/0N3TC3Tq2T
# Higher perspective
# Higher Perspective  https://www.facebook.com/HigherPerspective/videos/1240736959291954/
# <3 Higher Perspective  https://www.facebook.com/HigherPerspective/videos/1245392452159738/
# ❤️ Higher Perspective ❤️ http://twitter.com/JustMel1963/status/743673659173175298/photo/1
# Higher perspective... @swimmacc coachkimi @johnfedena @courtneyconn4… https://t.co/Z16zmhr8g6
# Higher Perspective https://t.co/ugaTzCOky3
#
# Topic (10) Number of Tweets: 12, D: 6.29595923578
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'via', 12), (u'golden', 1), (u'viralhog', 1), (u'purewow', 1), (u'finding', 1), (u'shared', 1), (u'primer', 1)]
#
# Phrases:
#
# Examples:
# https://t.co/L4cl2FKmJK via @tableaupublic @narendramodi @PMOIndia @makeinindia @startupindia @GirlsWhoCode http://twitter.com/ScrawlingTekst/status/744744313108717568/photo/1
# All you have to do is... http://spr.ly/6184BtpAM via PureWow  http://spr.ly/6184BtpAM
# #no is golden https://t.co/To3P32iayn via @yoganonymous @cherylstrayed
# #NAWBOSanDiego shared via @my1218apps #nawbola16 @NAWBONational http://twitter.com/1218appteam/status/744042978197536768/photo/1
# Finding #Balance With #Essential #Oils  https://t.co/jlfW87hEGY via @yoganonymous @vhotlogic
# #Summer #Solstice #Yoga #Sequence #Infinite #Potential https://t.co/msn2E91qCg  via @yoganonymous
# @IGNITE_National here's my primer via @AAUW https://t.co/pJ4T66JwFY
# https://t.co/rLK5Y6EBv8 via @YourStoryCo @YS_Bangla  @UrduYourstory @_SocialStory @WomenOdisha  @WomenEnt @herstoryYS #ManjulaBaghela
# https://t.co/dh0VQ8cebB https://t.co/6xYany4BEt via @melanieduncan7
# About - https://t.co/gSvuRT1VAL via @melanieduncan7
#
# Topic (11) Number of Tweets: 21, D: 6.60291265886
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'luncheon', 19), (u'may', 17), (u'2016', 17), (u'networking', 1), (u'la', 1), (u'nawbo', 1), (u'dinner', 1), (u'accelerated', 1), (u'awards', 1), (u'gala', 1)]
#
# Phrases:
# luncheon may 2016 (17)
# ewomennetwork accelerated networking luncheon (1)
#
# Examples:
# NAWBO-LA Awards Luncheon   #nawbo  #women  #business #awardsluncheon… https://t.co/8voK1dUTNa
# 'eWomenNetwork's 'Accelerated Networking' Luncheon!' on @LinkedIn https://t.co/vJHj5kF40Z
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/LqB9pcX0Uo
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/0P8N0EIUBb
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/Ghrp7YYM7U
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/CEDNBesssz
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/sceo8vuiXB
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/vHmL7nrA8N
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/3KIt3taKPa
# #eWomenNetwork #Austin luncheon, May 2016. https://t.co/LGHLLqXAP3
#
# Topic (12) Number of Tweets: 22, D: 7.92599566664
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'movement', 21), (u'social', 19), (u'evolver', 18), (u'3', 3), (u'supporting', 1), (u'via', 1), (u'media', 1), (u'hashtag', 1), (u'intellectual', 1), (u'important', 1)]
#
# Phrases:
# 3 evolver social movement (3)
# important social media movement (1)
#
# Examples:
# <3 Evolver Social Movement  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154234656992731/?type=3
# This is such an important social media movement.  http://trib.al/RZhLQts
# @GirlsWhoCode @Medium @emilyerinreid I'm supporting the movement
# Evolver Social Movement  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154226137157731/?type=3
# Evolver Social Movement  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154227438767731/?type=3
# Evolver Social Movement  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154224287477731/?type=3
# <3 Evolver Social Movement  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154223079547731/?type=3
# Evolver Social Movement  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154221201837731/?type=3
# Evolver Social Movement  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154215814272731/?type=3
# Via Evolver Social Movement  https://www.facebook.com/photo.php?fbid=495614070642472&set=p.495614070642472&type=3
#
# Topic (13) Number of Tweets: 11, D: 8.28800400642
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'true', 9), (u'bravely', 2), (u'step', 2), (u'worth', 2), (u'totally', 1), (u'exists', 1), (u'vacation', 1), (u'miracle', 1), (u'lifetime', 1), (u'dream', 1)]
#
# Phrases:
# bravely step true worth (2)
# true vacation miracle (1)
#
# Examples:
# True!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1170380556368142/?type=3
# So, So, So, true @officialJimRohn http://twitter.com/BeyondPlaybook/status/744364512166486016/photo/1
# @TheMarySue @Triskelian It's so true! #TylerHoechlin
# @kayan_leung true :) @ChangeAgentSA @BrentLindeque @missearth_sa @Abramjee @LeadershipPform @GdnWomenLeaders @Yali_RLCSA @sa_fusion
# The dream exists.  http://www.purewow.com/money/best-jobs-to-work-from-home?utm_medium=social&utm_source=facebook
# Bravely Step Into Your True Worth https://t.co/XxbK4CUpI3
# Bravely Step Into Your True Worth  #yoganonymous https://t.co/bfpPZOWzDS
# @TheMarySue totally true!
# So, So, So, true @officialJimRohn http://twitter.com/BeyondPlaybook/status/741465248285229056/photo/1
# A true vacation miracle.  http://www.purewow.com/fashion/how-to-pack-a-necklace?utm_medium=social&utm_source=facebook
#
# Topic (14) Number of Tweets: 13, D: 9.51871291117
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'trek', 10), (u'coding', 9), (u'game', 9), (u'journey', 1), (u'fishing', 1), (u'bye', 1), (u'trip', 1)]
#
# Phrases:
# trek game coding (9)
#
# Examples:
# @ronnie_yfe fishing trip?🎣🤔 @MauiDinho10
# Bye!  https://www.facebook.com/HigherPerspective/photos/a.488358504529807.114722.488353241197000/1246579598707690/?type=3
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/TulsaSTEM/status/743936291721650176/photo/1
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/TulsaSTEM/status/743898910192611328/photo/1
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/TulsaSTEM/status/743898853548515328/photo/1
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/TulsaSTEM/status/743898806459109376/photo/1
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/brkSTEMglass/status/743882511030198272/photo/1
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/TulsaSTEM/status/743882423860002817/photo/1
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/TulsaSTEM/status/743877377223077888/photo/1
# @MicrosoftStore-Tech Trek  Game Coding@SchustermanFoun #PoweredByFlightNight @AAUW http://twitter.com/TulsaSTEM/status/743877299527790596/photo/1
#
# Topic (15) Number of Tweets: 37, D: 9.96843244371
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'code', 31), (u'confidence', 31), (u'kay', 31), (u'katty', 31), (u'shipman', 31), (u'claire', 31), (u'careers', 11), (u'awte', 5), (u'ko', 4), (u'ang', 2)]
#
# Phrases:
# confidence code katty kay claire shipman careers (11)
# sa awc shit (1)
#
# Examples:
# The Confidence Code - Katty Kay &amp; Claire Shipman | #Careers... https://t.co/0YQOybqwpA
# The Confidence Code - Katty Kay &amp; Claire Shipman | #Careers... https://t.co/OjlhjoxI7g
# @berkeleyjess The Confidence Code by Katty Kay and Claire Shipman. preview here: https://t.co/hkxNduLcu9
# The Confidence Code - Katty Kay &amp; Claire Shipman | #Careers... https://t.co/D0rRQFMX4M
# The Confidence Code - Katty Kay &amp; Claire Shipman | #Careers... https://t.co/cMPiUq009m
# The Confidence Code - Katty Kay &amp; Claire Shipman | Careers... https://t.co/brl91k9nPz #Careers
# The Confidence Code - Katty Kay &amp; Claire Shipman | Careers... https://t.co/YiF2nlKiWv #careers
# Kaso pati kulay ng buhok pinapakialaman. Awte hahaha
# The old book cover of AWC by @dearbarbs, natandaan ko 'to. Kaiyak, medyo nahihiya ako nung ibinigay ko 'to. http://twitter.com/rascotta/status/744192341951582208/photo/1
# The Confidence Code - Katty Kay &amp; Claire Shipman | #Careers... https://t.co/qlJoTuOLLf
#
# Topic (16) Number of Tweets: 17, D: 11.5041479907
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'learned', 10), (u'lessons', 8), (u'judge', 5), (u'everyone', 4), (u'keeping', 4), (u'v', 4), (u'learn', 3), (u'learning', 2), (u'things', 2), (u'kripalu', 2)]
#
# Phrases:
# lessons judge learned keeping everyone v (4)
# 10 things learned kripalu (2)
#
# Examples:
# 35 lessons I learned turn 35 https://t.co/exCssNDCRl #bossbabe #entrepeneurship
# Here are some of the lessons #MasterChef Judge @ChristinaTosi has learned about keeping up with everyone. V @WomenEnt
# Here are some of the lessons #MasterChef Judge @ChristinaTosi has learned about keeping up with everyone. V @WomenEnt
# Here are some of the lessons #MasterChef Judge @ChristinaTosi has learned about keeping up with everyone. V @WomenEnt
# Here are some of the lessons #MasterChef Judge @ChristinaTosi has learned about keeping up with everyone. V @WomenEnt
# Learn how to #monetize your coaching practice with these 3 proven tips from @eWomenNetwork https://t.co/MqN5UP603d http://twitter.com/sandrayanceyEWN/status/740233619784884224/photo/1
# Yesterday's volunteers from @Shell_Martinez, @BofA, &amp; @NCWIT. Volunteers make lessons more fun! @MtDiabloUSD http://twitter.com/MDUSDGIRLCamp/status/743175421781434368/photo/1
# @JaneE_AWC Facinating what you can learn at a conference!
# 10 Things I Learned From Kripalu  #yogababaji https://t.co/90MKJY5pl8
# 10 Things I Learned From Kripalu https://t.co/4vdH8zZ1J1
#
# Topic (17) Number of Tweets: 22, D: 11.9341394823
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'words', 20), (u'idil', 9), (u'ahmed', 8), (u'hoppes', 2), (u'dr', 2), (u'seuss', 2), (u'amanda', 2), (u'stefanovic', 1), (u'zdravko', 1), (u'powerful', 1)]
#
# Phrases:
# words idil ahmed (8)
# words amanda hoppes (2)
#
# Examples:
# words: Idil Ahmed  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154226158502731/?type=3
# words: Idil Ahmed  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154226271017731/?type=3
# @iamthatgirl @saskdraws such powerful, motivating words!
# words: Idil Ahmed  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154226137157731/?type=3
# words of wisdom: Gareth Egan  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154226209337731/?type=3
# Transcript: #BernieSanders speech in Burlington, #Vermont  https://t.co/xzWjRcE8Jt  #BRAVO #OurRevolution @DFAaction @BoldProgressive @AAUW
# words: Idil Ahmed  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154224287477731/?type=3
# words: Amanda Hoppes  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154213631997731/?type=3
# @SteveQuirk_TDA @TDANSherrod @AndySwan What name?
# words: Brendon Burchard  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154221005882731/?type=3
#
# Topic (18) Number of Tweets: 25, D: 11.9645764859
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'via', 23), (u'stories', 23), (u'news', 17), (u'ewomennetwork', 12), (u'victoria', 12), (u'superhero', 3), (u'heard', 3), (u'daily', 3), (u'tcu', 1), (u'entrepreneur', 1)]
#
# Phrases:
# heard superhero news stories via (3)
# daily stories via (3)
#
# Examples:
# eWomenNetwork Victoria News is out! https://t.co/m4blwMdcQn
# eWomenNetwork Victoria News is out! https://t.co/4nRxRnJ2Uy Stories via @sharimolchan @eWomenNetwork
# Stories via  @TheWrap  @cinemablend  @TheMarySue  @techinsider  @abduzeedo  @openculture   #FXJBNewsFeed
# eWomenNetwork Victoria News is out! https://t.co/y5dRu7h0w8 Stories via @JUHLiSELBy @EngagedHR
# .RT @RealtyTeacher: eWomenNetwork Victoria News is out! https://t.co/dCOue9VORe Stories via @cheryl_relf @kerrybrowncoach @LisaLarter
# Have You Heard the Superhero News? https://t.co/mgXqv3scBD #superheroes #news Stories via @SamMaggs @HeatVisionBlog @TheMarySue
# The TCU Entrepreneur Daily is out! https://t.co/AajLQCA6H4 Stories via @WomenEnt @wadhwa @richardbranson
# eWomenNetwork Victoria News is out! https://t.co/X8mdM0EhOb Stories via @cheryl_relf @kerrybrowncoach @LisaLarter
# Change Through Action Weekly is out! https://t.co/yiTIr79A0w Stories via @leadchangegroup @GdnWomenLeaders @AlbPresby #leadchange #albpresby
# eWomenNetwork Victoria News is out! https://t.co/0keP8DS9Qs Stories via @carolwain @eWomenNetwork @gowestgroup
#
# Topic (19) Number of Tweets: 18, D: 12.3034606754
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'poet', 18), (u'becca', 3), (u'lee', 3), (u'rune', 3), (u'lazuli', 3), (u'nayyiriah', 1), (u'attic', 1), (u'ashourina', 1), (u'actor', 1), (u'steffi', 1)]
#
# Phrases:
# poet rune lazuli (3)
# poet becca lee (3)
#
# Examples:
# poet: Rune Lazuli  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154234656992731/?type=3
# poet: becca lee  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154231954762731/?type=3
# poet: Steffi  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154231905512731/?type=3
# poet: zachry k. douglas  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154230989747731/?type=3
# poet: jen fountain  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154224154537731/?type=3
# poet: Madalyn Beck  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154227438767731/?type=3
# poet; Marco Briano ~ ligurianpoet  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154221933087731/?type=3
# poet: rune lazuli  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154223316702731/?type=3
# poet: nayyiriah waheed  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154223315747731/?type=3
# poet: rose hummingbird  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154220863952731/?type=3
#
# Topic (20) Number of Tweets: 13, D: 12.6466373232
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'yay', 8), (u'thx', 3), (u'4', 3), (u'ohmygod', 1), (u'seeing', 1), (u'hufflepuffs', 1), (u'yea', 1), (u'scrappy', 1), (u'ty', 1), (u'fixed', 1)]
#
# Phrases:
#
# Examples:
# Yea do that  https://t.co/3IWmdSUZtI
# .@GCGodfrey @sloan_phil @Soundbuy @BeazleyGroup @insurtechforum @treesieT @MunichRe @bold_penguin @jendor_ski Thx 4❤/RT🙏😃#TRADING #FINTECH
# Yay Nicole! @TDANSherrod https://t.co/r5NZ9bdSr6
# @KappaDeltaUTC @ScrappyUTC @UTChattanooga @KappaDeltaHQ Yay Scrappy!
# @TDANSherrod ty ma'am
# .@GCGodfrey @dinisguarda @BeginerTrader @DianaEPatterson @mendizale44 @reb40 @immikhan @pbrat40plus @olopopworld @stefbj Thx 4❤/RT🙏😃#TRADING
# @lydia_petze @TheMarySue OHMYGOD YAY
# @TheMarySue fixed, yay
# yay for me 😊 https://t.co/wH8Bmr4szk
# .@GCGodfrey @DianaEPatterson @cooke_rich @SureDividend @wheeliedealer @TheRumTraderLSE @clairenfc @jacobward_11 Thx 4❤/RT🙏😃#TRADING #FINTECH
#
# Topic (21) Number of Tweets: 13, D: 13.0214365558
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'via', 5), (u'tip', 5), (u'purewow', 5), (u'sink', 5), (u'weekend', 5), (u'kitchen', 5), (u'clean', 5), (u'quick', 5), (u'heavy', 1), (u'garbage', 1)]
#
# Phrases:
# quick kitchen tip weekend via purewow clean sink (5)
# break bank gas (1)
#
# Examples:
# How heavy is the glass of water?  https://www.facebook.com/HigherPerspective/videos/1248148238550826/
# تقدم إحدى المشاركات عرضها لطريقة حلها لأول تمرين معهم في كورس #cs50 باستخدام Scratch #developement #womeninstem http://twitter.com/GazaSkyGeeks/status/744875988224348161/photo/1
# #4. We share cooking and chores evenly.  http://trib.al/jtCehZ9
# Don't break the bank on gas  http://www.purewow.com/money/8-ways-to-save-on-summer-road-trips?utm_medium=social&utm_source=facebook
# This bath IS luxury.  http://trib.al/9tMeu55
# @attn @iamthatgirl this is garbage
# It's all messy...  https://www.facebook.com/HigherPerspective/photos/a.488358504529807.114722.488353241197000/1244774315554885/?type=3
# A quick kitchen tip for this weekend. via PureWow   Clean your sink too: http://huff.to/1rh584e  https://www.facebook.com/HuffPostCanadaLiving/videos/1047159188653477/
# A quick kitchen tip for this weekend. via PureWow   Clean your sink too: http://huff.to/1rh5LdW  https://www.facebook.com/HuffPostAlberta/videos/1406635652695183/
# A quick kitchen tip for this weekend. via PureWow   Clean your sink too: http://huff.to/1rh4XWv  https://www.facebook.com/huffpostcanadaparents/videos/1093663680680004/
#
# Topic (22) Number of Tweets: 51, D: 13.1882292794
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'photo', 51), (u'added', 43), (u'new', 43), (u'evolver', 38), (u'social', 38), (u'movement', 38), (u'jim', 6), (u'rohn', 6), (u'yoganonymous', 5), (u'love', 1)]
#
# Phrases:
# jim rohn added new photo (6)
# photo booth action (1)
#
# Examples:
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154233216467731/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154234456372731/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154233255662731/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154232873872731/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154231766322731/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154231904302731/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154223319372731/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154227432837731/?type=3
# Jim Rohn added a new photo.  https://www.facebook.com/OfficialJimRohn/photos/a.10150825389085635.734328.317351405634/10157004028750635/?type=3
# Evolver Social Movement added a new photo.  https://www.facebook.com/evolversocialmovement/photos/a.346958347730.154009.309517367730/10154218746067731/?type=3
#
# Topic (23) Number of Tweets: 54, D: 13.6919072513
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'gear', 53), (u'juice', 52), (u'giving', 50), (u'pressed', 50), (u'away', 48), (u'workout', 48), (u'enter', 30), (u'sick', 25), (u'win', 3), (u'38', 2)]
#
# Phrases:
# giving away gear pressed juice enter (4)
#
# Examples:
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear &amp; juice.  https://t.co/BAFl2LCor3
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear &amp; juice.  https://t.co/bNiKLgyVqY
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some workout gear &amp; pressed juice: https://t.co/gH2zYjZwjj
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some workout gear &amp; pressed juice! https://t.co/tYJwJz3RLu
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous  giving away workout gear &amp; pressed juice. Enter! https://t.co/QsT0miGJcN
# .@loremipsum_wtf,@heybloom,@wellwell,@carbon38&amp; @yoganonymous giving away some workout gear &amp; pressed juice. Enter! https://t.co/YhsmRvCCSj
# .@loremipsum_wtf, @heybloom, @carbon38 &amp; @yoganonymous are giving away some sick workout gear &amp; pressed juice. Enter https://t.co/yY1jGZWwPu
# @loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away workout gear &amp; pressed juice Enter! https://t.co/OSdeJmzn5G
# @loremipsum_wtf @heybloom @wellwell @carbon38 &amp; @yoganonymous giveway of sick workout gear &amp; pressed juice. Enter! https://t.co/4kcjNBlVpk
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away sick workout gear &amp; pressed juice! https://t.co/w99d1g2mG4
#
# Topic (24) Number of Tweets: 20, D: 14.3385510494
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'thanks', 20), (u'sharing', 6), (u'many', 2), (u'much', 2), (u'love', 1), (u'4', 1), (u'bro', 1), (u'link', 1), (u'reminder', 1), (u'shoutout', 1)]
#
# Phrases:
# love thanks sharing (1)
# thanks much sharing (1)
#
# Examples:
# @TheMarySue Thanks for sharing! #swapped
# @yfe_wiz thanks bro
# @tanyarezak @potterhockey @TheMarySue thanks!
# @attn @iamthatgirl LOVE this. Thanks for sharing!
# @GdnWomenLeaders @guardian thanks for this. It's encouraged me!
# #FF and thanks! @Lemieux_26 @Sentifi_UK @Percy_Peru @GCGodfrey @MarieQuantier @StakepoolCom @thesaddleguy1 @mytradingbuddy @AzizSapphire
# @marjo_yfe will do, thanks 😘😘😘
# @YOGANONYMOUS @LaMues thanks so much for sharing!
# Thanks @GoogleForEdu + @TataCompanies @Microsoft @qventures @CSNYC @csteachersa @NCWIT @NSF @WhiteHouse. #CSForAll https://t.co/gjr0J6AX1Y
# @YOGANONYMOUS @anniek1963 thanks for sharing !
#
# Topic (25) Number of Tweets: 32, D: 14.7064077992
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'happy', 31), (u'birthday', 29), (u'members', 19), (u'love', 1), (u'weekend', 1), (u'celebrating', 1), (u'go', 1), (u'brodie', 1), (u'guys', 1), (u'saturday', 1)]
#
# Phrases:
# cousins ily much (1)
# cake esp birthday (1)
#
# Examples:
# Happy birthday @RepDonBeyer from @AAUW &amp; our members in #Virginia!
# @ronnie_yfe happy birthday Ronnie! ❤️
# Happy birthday @ronnie_yfe ✊🏿💯
# happy birthday Brodie!!🤘🏽🎉 @ronnie_yfe
# Happy birthday to my favorite twins ❤️❤️ @ronnie_yfe @kenzonthecob
# happy birthday cousins ily so much 💞💞💞 @kenzonthecob @ronnie_yfe
# Happy birthday love you guys ❤️❤️❤️ @ronnie_yfe @kenzonthecob
# Happy #InternationalYogaDay @Yoga_Journal @YOGANONYMOUS @YogaBear @Devesh_Tamta @goodhealth @MantraYogaMag @mcyogi http://twitter.com/vini_yoga/status/744781268466839553/photo/1
# @JoC_AWC GO JO! And Happy birthday 🎈🎉🍰💕
# @JoC_AWC  Happy Birthday bella!
#
# Topic (26) Number of Tweets: 27, D: 15.1386560846
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'photos', 20), (u'album', 16), (u'posted', 15), (u'facebook', 12), (u'video', 8), (u'2', 7), (u'added', 5), (u'awc', 5), (u'instagram', 4), (u'3', 4)]
#
# Phrases:
# sophia amoruso added 2 new photos album instagram photos (4)
# photos facebook album ewomennetwork (4)
#
# Examples:
# Just posted a photo @ Universiti Malaysia Pahang (UMP) https://t.co/duivCTDOq0
# Had to repost this now that official video is out. ROMAIN VIRGO 'GENERAL' - &gt; https://t.co/XxGbxVC4aO   @zjrush http://twitter.com/Disc2DiscOnline/status/744183940525613057/photo/1
# Sophia Amoruso added 2 new photos to the album: Instagram Photos.  https://www.facebook.com/sophiaofnastygal/photos/a.1048069225235747.1073741826.433733193336023/1190850344290967/?type=3
# NAWBO Promo Video: https://t.co/uMLePGI4WM via @YouTube
# I posted 4 photos on Facebook in the album 'AWC Cream on White Windows' https://t.co/0pYqRdfoir
# I posted 58 photos on Facebook in the album 'AWC Aluminium Composite Doors' https://t.co/GIJcpS6j2P
# Sophia Amoruso added 2 new photos to the album: Instagram Photos.  https://www.facebook.com/sophiaofnastygal/photos/a.1048069225235747.1073741826.433733193336023/1190405361002132/?type=3
# VIDEO: What About #FatherFULLness? https://t.co/z3gyRjWbhM @NAEYC @edutopia @edvotes @pbsteachers @TeachForAmerica @ScholasticTeach @AAUW
# I posted 5 photos on Facebook in the album 'eWomenNetwork 'Accelerated Networking' Luncheon' https://t.co/LXpzvWi4kf
# I posted 3 photos on Facebook in the album '#NAWBO Advocacy Day in DC' https://t.co/Rq6qELghz3
#
# Topic (27) Number of Tweets: 40, D: 16.2353996337
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'away', 38), (u'giving', 35), (u'enter', 32), (u'gear', 29), (u'workout', 29), (u'sick', 28), (u'give', 3), (u'juice', 2), (u'r', 1), (u'workoutpressed', 1)]
#
# Phrases:
# giving away sick workout juice enter (1)
#
# Examples:
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear  Enter! https://t.co/rZe0GKEcN3
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear  Enter! https://t.co/gfpmZEs33Y
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear  Enter! https://t.co/QTJXlRVh7O
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear  Enter! https://t.co/gfpmZEJEsy
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear Enter! https://t.co/VMJg68Xjid
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear Enter! https://t.co/gfpmZEJEsy
# Give it away now!  http://www.purewow.com/entertainment/red-hot-chili-peppers-shirtless-carpool-karaoke?utm_medium=social&utm_source=facebook
# It's all about the practice >>  http://yoganonymous.com/quote-of-the-week-yoga-is-99-practice-1-theory
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous . Enter! https://t.co/wYkcxd1wEo
# .@loremipsum_wtf, @heybloom, @wellwell, @carbon38 &amp; @yoganonymous are giving away some sick workout gear Enter! https://t.co/gfpmZEJEsy
#
# Topic (28) Number of Tweets: 33, D: 19.4500574236
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'shop', 26), (u'via', 24), (u'mary', 24), (u'sue', 24), (u'giveaway', 24), (u'card', 13), (u'gift', 10), (u'1000', 9), (u'herschel', 7), (u'travel', 7)]
#
# Phrases:
# gift card giveaway mary sue shop via (9)
# ultimate herschel travel bundle giveaway mary sue shop via (7)
#
# Examples:
# Shop Today! #virginhair #wigs #girlboss http://twitter.com/IHustlePretty/status/744884289666351105/photo/1
# @WomenEnt @YoungEnt @truetrae @jessicaabo @ErinESchultz Gift card because we really don't care 😜
# @hamboky @TDANSherrod @TDAmeritrade Don't pay - here's how to not pay https://t.co/2oMC30TOGa
# The Ultimate Herschel Travel Bundle Giveaway | The Mary Sue Shop https://t.co/Meqy5jEX43 via @TheMarySue
# The Ultimate Herschel Travel Bundle Giveaway | The Mary Sue Shop https://t.co/ArIJUG2UKs via @TheMarySue
# The Ultimate Herschel Travel Bundle Giveaway | The Mary Sue Shop https://t.co/fJlbnz8GiE via @TheMarySue
# The Ultimate Herschel Travel Bundle Giveaway | The Mary Sue Shop https://t.co/D44wUnttrJ via @TheMarySue
# @WomenEnt  You can get CrowdFunded CashBack from a Prepaid Card! You have to check this out: https://t.co/xTebvZ8thS http://twitter.com/honeykfyi/status/743189897029226496/photo/1
# @WomenEnt  You can get CrowdFunded CashBack from a Prepaid Card! You have to check this out: https://t.co/xTebvZ8thS http://twitter.com/honeykfyi/status/743189614538723329/photo/1
# @WomenEnt @YoungEnt    You can get CrowdFunded CashBack from a Prepaid Card! You have to check this out:    https://t.co/xTebvZ8thS
#
# Topic (29) Number of Tweets: 19, D: 20.0105911692
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'soul', 8), (u'mindful', 7), (u'preach', 6), (u'heart', 2), (u'afraid', 2), (u'hearts', 2), (u'intimacy', 2), (u'old', 1), (u'spirituality', 1), (u'prayers', 1)]
#
# Phrases:
# well bless heart (1)
# spirituality religion thing (1)
#
# Examples:
# @kleffnotes @TheMarySue many prayers to them all
# Mindful Soul  https://www.facebook.com/themindfulsoul/photos/a.1033947293283028.1073741826.1031950900149334/1282429615101460/?type=3
# Hearts. Broken.  http://trib.al/0tWK0Fb
# Mindful Soul  https://www.facebook.com/themindfulsoul/photos/a.1033947293283028.1073741826.1031950900149334/1281404655203956/?type=3
# Are you afraid of intimacy?  http://dailyvibes.org/overcome-fear-intimacy/?c=hp
# Mindful Soul  https://www.facebook.com/themindfulsoul/photos/a.1033947293283028.1073741826.1031950900149334/1280099435334478/?type=3
# Well bless her heart.  http://www.purewow.com/entertainment/googling-grandma?utm_medium=social&utm_source=facebook
# Mindful Soul  https://www.facebook.com/themindfulsoul/photos/a.1033947293283028.1073741826.1031950900149334/1279217742089314/?type=3
# Mindful Soul  https://www.facebook.com/themindfulsoul/photos/a.1033947293283028.1073741826.1031950900149334/1278886252122463/?type=3
# Preach!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1166211923451672/?type=3
#
# Topic (30) Number of Tweets: 41, D: 22.5370860678
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'v', 41), (u'get', 8), (u'founder', 4), (u'talks', 4), (u'fear', 4), (u'theranos', 4), (u'2014', 4), (u'regrets', 4), (u'gave', 4), (u'means', 4)]
#
# Phrases:
# discrimination stance v (4)
# dzana homan talks super (4)
#
# Examples:
# ScrawlingBetaTest in 12h.Lets c hw v fair #startupindia #myfirstTweet @makeinindia @investindia @GirlsWhoCode http://twitter.com/ScrawlingTekst/status/744724780264349698/photo/1
# ScrawlingBetaTest in 12h. Lets c hw v fair. #startupindia #myfirstTweet @makeinindia @investindia @GirlsWhoCode @betaout
# Acknowledging some of the fearless females who broke down barriers. V @WomenEnt
# Acknowledging some of the fearless females who broke down barriers. V @WomenEnt
# Acknowledging some of the fearless females who broke down barriers. V @WomenEnt
# Acknowledging some of the fearless females who broke down barriers. V @WomenEnt
# Get ready for a movie about Theranos founder Elizabeth Holmes, played by J-Law. V @WomenEnt
# Get ready for a movie about Theranos founder Elizabeth Holmes, played by J-Law. V @WomenEnt
# Get ready for a movie about Theranos founder Elizabeth Holmes, played by J-Law. V @WomenEnt
# Get ready for a movie about Theranos founder Elizabeth Holmes, played by J-Law. V @WomenEnt
#
# Topic (31) Number of Tweets: 39, D: 24.0809487931
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'relationship', 39), (u'rules', 25), (u'shared', 19), (u'photo', 14), (u'things', 7), (u'new', 5), (u'video', 5), (u'post', 5), (u'added', 5), (u'truth', 3)]
#
# Phrases:
# relationship rules shared photo truth (3)
#
# Examples:
# Relationship Rules shared their post.:7 ways to know whether your man is a player or a keeper!  http://rrul.es/1SJR10L
# Relationship Rules shared their photo.:Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1149089608497237/?type=3
# Relationship Rules shared their post.:If he does these things, never let him go. He's a keeper!  http://goo.gl/qsA6yU
# Relationship Rules shared their video.:If you ever fall in love...  https://www.facebook.com/RelationshipRules/videos/1165205386885659/
# Relationship Rules shared their photo.:Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1154327564640108/?type=3
# Relationship Rules shared their photo.:Truth!  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1155624781177053/?type=3
# Relationship Rules shared 1-Minute Motivations's video.:6 things you need to start doing for yourself today...  https://www.facebook.com/1minmotivations/videos/1685746358353709/
# Relationship Rules shared their photo.:Pass it on <3  https://www.facebook.com/RelationshipRules/photos/a.399370053469200.95216.399369750135897/1157807960958735/?type=3
# Relationship Rules shared their post.:Only Real Men would do these things.  http://goo.gl/iVJHyF
# 9 ways to fight insecurities in your relationship..  http://www.relrules.com/9-ways-to-fight-insecurities-in-your-relationship/
#
# Topic (32) Number of Tweets: 28, D: 24.283837731
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'look', 17), (u'get', 11), (u'wearing', 6), (u'gorgeous', 5), (u'wow', 4), (u'looks', 2), (u'dress', 2), (u'take', 2), (u'beaut', 2), (u'see', 2)]
#
# Phrases:
# get gorgeous look (2)
# looking incredible get (1)
#
# Examples:
# .@SHEROESIndia @GirlsWhoCode @IBMer_IN @IBM @sandy_carter @Sairee @GayatriiM See this  https://t.co/oVgB9A8RZQ #Coding #STEM #WomeninTech
# Wow...  https://www.facebook.com/HigherPerspective/videos/1245392452159738/
# My look at #FindingDory over at @TheMarySue  https://t.co/xhszOt2lDU
# @Sfrichck @TheMarySue Wow
# Get @Faye_Brookes' gorgeous look from @Topshop now: https://t.co/owMYMVkgCV http://twitter.com/JenSt1988/status/744221783096627200/photo/1
# This is too cute not to see.  http://trib.al/FuGkUlg
# @MDUSDGIRLCamp @TesoroCorp @BankofAmerica @NCWIT @Shell @sprint @MtDiabloUSD All I can say is WOW!
# ...
# @AmelieSaintonge a start. Hope pull thro' effect for young women in commnity. Tech team less so; need to merge @GirlsWhoCode w/astrophysics!
# Thursday 23rd: IOM3 Women in Materials: National Women in Engineering Day, University of Warwick https://t.co/hNPLtU272j #womeninSTEM
# RT - Tocacyy: Redcage Solutions: 'What better way to be different than to be a female leader?' #womenintech #leade… https://t.co/NxVW55lCFr
# https://t.co/YgLxBtdTa0 is a semifinalist at the Global Entrepreneurship Summit's pitch competition @ges2016 @TheStartupHour @WomenEnt
# TECHNOLOGY WOMEN - Miss Michigan, Arianna Quan studies Auto Design at College for Creative https://t.co/ULewdvd9ax #WomenInSTEM @WomeninMfg
# Why this high school girl skipped graduation to attend Apple's developer conference https://t.co/TxRYw0whRA #womenintech
# #Rhona_Silver is the member of #eWomenNetwork Foundation Council and the Committee of 200 (c200). https://t.co/uGixPaSHEk
#
# Topic (67) Number of Tweets: 161, D: 134.340387912
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'know', 26), (u'never', 18), (u'want', 15), (u'let', 12), (u'think', 12), (u'say', 12), (u'anyone', 11), (u'things', 10), (u'love', 9), (u'something', 9)]
#
# Phrases:
# let us know (4)
# happens anyone code find (3)
#
# Examples:
# Would you be interested in us hosting a #womenintech event @unilincoln? Let us know https://t.co/mGMdcoV3pr
# What Are You Really Afraid of in Your Business? https://t.co/KRuwzTM6nP via @melanieduncan7
# 'It always seems impossible until it's done.' #motivationalmonday #nelsonmandela #girlboss https://t.co/O1e027aLa4
# If you can't stop thinking about it, Just Do It! #Quote #Truth #Entrepreneur #Boss #BossMentality #GirlBoss
# 9 things men want but never ask for...  http://www.relrules.com/9-things-men-want-but-never-ask-for/
# You have to try THIS!  http://www.simpleorganiclife.org/drinking-turmeric-water-1865417771.html?c=hp
# @rucsb by 'us' whom do you mean? Anyone can learn from CodeAcademy. @Sairee @sandy_carter @GirlsWhoCode
# @rucsb Anything that exists as of now? @GirlsWhoCode @IBMer_IN @IBM @sandy_carter @sairee #womenintech
# Those few people mean everything to me...  https://www.facebook.com/HigherPerspective/photos/a.488358504529807.114722.488353241197000/1247392631959720/?type=3
# If this burger is wrong, we don’t want to be right.  http://www.purewow.com/food/Healthy-Summer-Grilling-Recipes?utm_medium=social&utm_source=facebook
#
# Topic (68) Number of Tweets: 210, D: 146.249629757
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'like', 29), (u'via', 13), (u'female', 12), (u'love', 11), (u'image', 11), (u'think', 9), (u'girls', 9), (u'get', 9), (u'looks', 8), (u'queen', 8)]
#
# Phrases:
# crazy higher perspective (4)
# narcissists sociopaths use (4)
#
# Examples:
# Even supermodels get their hearts broken.  http://trib.al/oheqn1Z
# “Success is liking yourself, liking what you do, and liking how you do it” Maya Angelou #slay #Monday #girlboss #qotd #empoweredwomen #getit
# 'Hustle then Party' is a #GirlBoss mantra! Show your hustler spirit with this mug + such --&gt; https://t.co/2dDi5vQlNl http://twitter.com/ColorHug/status/744866235490308096/photo/1
# Sometimes when the lid of a flip top tube opens it sounds like science is blowing me a kiss :) #WomenInScience #ScienceGrrl #WomenInSTEM
# RETWEET if you want a girl who's a dirty #slut sign up   🍒 https://t.co/HTwKtn3lzX 🍒 http://twitter.com/SexAddictFreak/status/744814166049861635/photo/1
# We still have questions about this movie.  http://trib.al/PA3roV7
# @MGeschwind @TheMarySue Nobody wins with Comic Sans.
# @marcyjcook @TheMarySue Haven't seen it yet, but looking forward to it. A bit apprehensive about what it will do to blue hippo tangs.
# The new Pixar short is so much happier than Lava.  http://trib.al/O2bWasG
# #WatchHowIManeuver I ain't wit the Twitter talk you do it for the low life 😂😂😂 https://t.co/jXS8ybkn3X
#
# Topic (69) Number of Tweets: 228, D: 149.606440832
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'via', 217), (u'purewow', 21), (u'enter', 20), (u'win', 18), (u'great', 14), (u'10', 13), (u'free', 12), (u'fandom', 12), (u'interview', 10), (u'seriously', 10)]
#
# Phrases:
# win seriously enter 12 via (10)
# enter win 10 yrs netflix via (8)
#
# Examples:
# Five Tips for Picking Images https://t.co/9V5YYOD6Yb via @MarketingProfs #PR #ContentMarketing
# Manorama: The Universe Beyond the Mind https://t.co/kVtHMUdSGu via @yoganonymous
# The Podcast Audience in 2016: Demographic and Listening Trends: https://t.co/sQN8L9i3eF via @MarketingProfs http://twitter.com/woley/status/744882762746736640/photo/1
# You can #NetflixAndChill for a decade - Enter to win the 10 yrs of Netflix #Giveaway: https://t.co/e4SvJKjX2F via @TheMarySue
# The Content Sharing Habits of Facebook Users : MarketingProfs https://t.co/KHYycrUIw9 via @marketingprofs
# Here are the US cities where #womenintech are most grossly underpaid https://t.co/xGucl2i58a via @businessinsider
# 42 awesome #womenintech making a difference during 2015 via @simoncocking &gt;&gt; https://t.co/HpoGidKFYi
# Hey @GirlsWhoCode! how could we change this? (Even as men!) (via @careerfoundry) #stopsexism http://twitter.com/Ben_UXDesign/status/744828462872072192/photo/1
# You can #NetflixAndChill for a decade - Enter to win the 10 yrs of Netflix #Giveaway: https://t.co/EWhAB2zyAS via @TheMarySue
# This coffee hack is a total game-changer.  http://trib.al/ORCuUaH
#
# Topic (70) Number of Tweets: 242, D: 180.198291816
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'week', 43), (u'time', 28), (u'one', 27), (u'next', 26), (u'get', 23), (u'today', 21), (u'take', 18), (u'see', 18), (u'day', 17), (u'year', 17)]
#
# Phrases:
# see happening month upcoming events one place (9)
# take workouts next level (8)
#
# Examples:
# @GinaVoytek @MarketingProfs @annhandley Ready to reply! #route2act http://twitter.com/Route2Act/status/744891092399697920/photo/1
# Another #Monday and another week to work toward big #goals #hustle #girlboss #freelancewriter
# .@MarketingProfs Meet us at the most exciting Stack Overflow event of the year on June 21: https://t.co/8CPz6IWXkk. Hope to see you there!
# Are You Missing a #Branding Opportunity? https://t.co/j22InUzSYU #itrtg #bizhour @TheMarySue http://twitter.com/SupersonicPlay/status/744885268709261312/photo/1
# If you were going to study your first #ProjectManagement #qualification which one? #prince2 #APM #womenintech #cyber
# Mood today, who's with me...💋 #mondaymotivation #mrsrodial #girlboss #bossbabe https://t.co/LnRDV2DJuI
# Looking forward to @CodingAllowed event tomorrow evening!! Around for drinks if you are?? #womenintech #womenindigital #digital #tech
# New Week New Goals.... #mamahil #bionicwoman #bossbabe #entrepreneur #phoenixrising #stylist… https://t.co/Cgu2V8kdAp
# Good morning! Wake up, it's time to hustle! #MorningMotivation #monday #girlboss http://twitter.com/SheaNuckols/status/744867447069519875/photo/1
# Our  'Game Changers' #video sees @JennySnapTech discuss #Startups #Coding &amp; #WomenInTech: https://t.co/EWI6PS3tJN http://twitter.com/innovateuk/status/744866188778475520/photo/1
#
# Topic (71) Number of Tweets: 247, D: 185.274110882
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'one', 39), (u'image', 26), (u'house', 24), (u'fight', 22), (u'end', 21), (u'people', 21), (u'voice', 19), (u'floor', 19), (u'standing', 19), (u'survivors', 18)]
#
# Phrases:
# thanks standing sexual assault survivors house floor voice matters fight end (10)
# ty standing sexual assault survivors house floor voice matters fight end (8)
#
# Examples:
# #WomenInSTEM with outside of the box thinking! :) #GraceHopper #ComputerScience http://twitter.com/STEMxmPodcast/status/744882582534270976/photo/1
# Except for when applying eye makeup... #girlboss https://t.co/K0kfXklVnE http://twitter.com/shannonlmattern/status/744877836184453121/photo/1
# ....#girlboss Aisling (while the boss is away󾌪) #love the sleeve detail 󾬐 https://t.co/gWwM4DI2xo
# What is it like to be a #womenintech, when it continues to be a man-dominated field? https://t.co/mW8RejmtnQ
# The Walking Dead Reportedly Filmed 11 Takes of Negan's Intro To Keep That Season Finale Secret https://t.co/SqTbMySyAI via @TheMarySue
# Help Your Hormones | Get Your Legs Up The Wall    https://t.co/EXQZkle7gO
# Star Trek Actor Anton Yelchin Unexpectedly Passes Away in Traffic Accident https://t.co/eomh34PQQH via @TheMarySue
# Finding Dory just broke major records.  http://trib.al/Wt5kJeS
# How do we as women get sold on the idea that youth is the river that leads to the sea of happiness? Stop and think about the layered set of lies that are dropped at our feet as we enter our 20s...  http://www.likeabossgirls.com/adulting-30-breakthrough/
# @MauiDinho10 @ronnie_yfe they were biting at kings yesterday!
#
# Topic (72) Number of Tweets: 288, D: 186.179040042
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'awc', 35), (u'bollywood', 32), (u'social', 32), (u'via', 31), (u'news', 28), (u'media', 25), (u'new', 22), (u'club', 18), (u'fan', 16), (u'women', 16)]
#
# Phrases:
# club shahid kapoor (5)
# media social media (5)
#
# Examples:
# Diversity in the #tech industry is not happening naturally, according to Dr. Diana Parry ► https://t.co/EjZMNNrfkD #WomenInTech
# The Super Falcons of Nigeria have won the AWC (African Women's Championship) more than any other African Womens football team.
# Maria Giudice of Autodesk: 'What better way to be different than to be a female leader?' #womenintech https://t.co/2BpYQguAu5
# We love working with the bestwi staff from all over the UK and EU #VoteRemain #WomenInTech #StrongerIn https://t.co/IzhqMrL5Oj
# Please join Femcity Greenville this week https://t.co/8BsTA2ihcv for our 'June Event' #femcity #Girlboss http://twitter.com/Femfessionals/status/744880198261215232/photo/1
# Ada Lovelace, the first computer programmer. #WomenInTech http://twitter.com/j_c_fitz/status/744871115466498049/photo/1
# #youtube Aretha Franklin - Bridge Over Troubled Water https://t.co/9rHXYkFo0i
# Congrats Belinda Shi! Female student makes history and heads to coding Olympics - https://t.co/UR1jScw0PG #GoogleAlerts #womenintech
# RT AdLibRecruit: Our chat with Jen Williams,Senior Software Developer nwplanet. Her career journey and some advice for #womenintech https…
# Galaxy https://t.co/asE2yfT4yD @redbubble aracılığıyla #ALLin216 #womaninbizhour #womenintech #zazzlebesties #designthinking #shoppershour
#
# Topic (73) Number of Tweets: 321, D: 189.097881219
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'awc', 80), (u'2', 35), (u'one', 30), (u'3', 29), (u'new', 27), (u'1', 27), (u'6', 27), (u'4', 26), (u'june', 26), (u'2016', 25)]
#
# Phrases:
# newair awc 270e 27 bottle compressor wine cooler newair (13)
# 00 9 00 pm (9)
#
# Examples:
# Calling all #womenintech @Avanadeinc is hiring at the @WITI Virtual Career Fair June 22 - SIGN UP NOW! https://t.co/oGedoHVmxP
# High-octane, CANDID debate across all talks &amp; panels @TLAWomeninTech #LDNTechWeek Onwards &amp; upwards! #womenintech http://twitter.com/shivvyjervis/status/744885640928591872/photo/1
# The AWC will be at the Capitol today singing today at 12:00 as a tribute to the Orlando victims and their... https://t.co/MAFz5qI9kp
# Your moment of #STEM: H/T @theskimm 4 shining light on women in #gaming!  #womenintech https://t.co/gtbWN0UdRw
# RT innovateuk: Our  'Game Changers' #video sees JennySnapTech discuss #Startups #Coding &amp; #WomenInTech: … http://twitter.com/innovateuk/status/744866188778475520/photo/1
# Spiral Galaxy https://t.co/IBPJVFDBEE aracılığıyla #ALLin216 #womaninbizhour #womenintech #zazzlebesties #designthinking #shoppershour
# #LDNTechWeek has begun! Fifth of tech firms in UK run by women, compared to 5% of FTSE 100 companies https://t.co/yABiy9u2ZE #womenintech
# RT innovateuk: Meet 1 of our #infocus #womenintech ambassadors SorayaJones12 in new #innovateblog … http://twitter.com/innovateuk/status/744855039534108672/photo/1
# Authentic auspicious enfield bikes up to persist shabby advanced india 2013: AwC https://t.co/GHbEh0boew
# The benefits apropos of using straight a paye adding machine: AWc https://t.co/diFn02ao6M
#
# Topic (74) Number of Tweets: 324, D: 212.708382297
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'get', 35), (u'live', 30), (u'yfe', 27), (u'via', 27), (u'go', 27), (u'listen', 24), (u'day', 24), (u'want', 23), (u'please', 23), (u'join', 22)]
#
# Phrases:
# www kaylaitsines com app (8)
# monday morning mantra get back flow via (4)
#
# Examples:
# Meditation Monday: Letting Go of Things That Do Not Serve You #mondaymeditation #LetItGo  https://t.co/IGso3Gv2dn
# Meditation Monday: Letting Go of Things That Do Not Serve You https://t.co/OD3EVzx2iE via @YOGANONYMOUS
# Let's synergize our ducks in a row! 50 cliches u need to stop writing and saying! [Infographic] https://t.co/MRCy07B6g2 via @marketingprofs
# Monday Morning Mantra: You Are Not Your Feelings via @YOGANONYMOUS https://t.co/IZtD719Azr http://twitter.com/jollybookbugs/status/744884856912371713/photo/1
# A little laugh for your Monday morning. (And we'd love it delivered, but we'll work for it, too.)  https://www.facebook.com/paconferenceforwomen/photos/a.100644398914.93532.36754858914/10153818656883915/?type=3
# Want to work in #Wayland, Massachusetts? View our latest opening: https://t.co/hUy34POxOu #Hospitality #stem #b2b #itjobs #womeninstem #GTT
# Happy Monday! Start your week right: let’s chat tomorrow!! 11:30amPST/2:30pmEST 💋 #bossbabe #mommytrepreneur #goals http://twitter.com/nross971/status/744877753179115520/photo/1
# Happy Monday! Start your week right: let’s chat tomorrow!! 11:30amPST/2:30pmEST 💋 #bossbabe #mommytrepreneur #goals http://twitter.com/kjones36TX/status/744877749509173248/photo/1
# Monday Morning Mantra: You are Enough https://t.co/TNJc7Cyoqk
# Grab the bag and go.  http://www.purewow.com/fashion/multi-tasking-items-to-pack?utm_medium=social&utm_source=facebook
#
# Topic (75) Number of Tweets: 553, D: 329.80113192
# -------------------------------------------------------------------------------------------
# Top Words:
# [(u'life', 155), (u'love', 114), (u'things', 98), (u'people', 89), (u'one', 81), (u'get', 77), (u'like', 70), (u'would', 60), (u'make', 58), (u'us', 57)]
#
# Phrases:
# like boss girls shared link (11)
# 10 things give happy via (8)
#
# Examples:
# @shiralazar Check out our feature, The Future According to Women. Think you'll dig it! https://t.co/nNkyF2gAHl #femalefutures #girlboss
# When you tell yourself that dreams only come true for others you're creating a BullShit #LimitingBelief  #Entrepreneur #Girlboss #Boss
# Don’t compare yourself to others. Be yourself, love yourself, accept your uniqueness. #smallbiz #momtrepreneur #Girlboss #WAHM
# #SocialSkim: Quick read to get caught up on what's happening in social! https://t.co/LlDiLTzvv7 @marketingprofs   #marketingtips #socialtips
# How do we inspire the next generation of #womenintech? It won't be easy – here’s what we can all do: https://t.co/aspDUCdXff @alphr
# 'If you show up authentically and consistently, for enough days in a row, the right people will find you.' https://t.co/dxUzrVGqUi #girlboss
# We do this every day with your thoughts! Manifest greatness! #girlboss #bossbabe #womeninbusiness #entrepreneur http://twitter.com/FITCommGirls/status/744880159996575744/photo/1
# Hate #Mondays? It's time to take control of your life. Let me show you how you can be a #bossbabe and leave your corporate job behind.
# This #Pediatrics #job might be a great fit for you: RN-Pediatrics - https://t.co/AZDMHJpcPN #STEM #WomenInStem #USA #Hiring
# Good content always has an objective; it’s created with intent. It therefore carries triggers to action. - @marketingprofs #quotes

# %%
model.most_similar('phone')
# Out:
# [(u'telephone', 0.822401762008667),
#  (u'cell_phone', 0.7831963896751404),
#  (u'cellphone', 0.7629483938217163),
#  (u'Phone', 0.7060798406600952),
#  (u'phones', 0.6894921064376831),
#  (u'landline', 0.6263924837112427),
#  (u'voicemail', 0.6252244710922241),
#  (u'caller_id', 0.6023746728897095),
#  (u'RingCentral_cloud_computing', 0.5935890078544617),
#  (u'telephones', 0.5929964780807495)]
